# %% [markdown]
# # Data Cleaning  Step -2

# %% [markdown]
# # Missing Value Imputation by Mean, Median

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\Data Cleaning\house-prices-advanced-regression-techniques\train.csv")

# %%
df.shape
# Out:
# (1460, 81)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
missing_value_per = df.isnull().sum()/df.shape[0]*100

missing_value_per
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType        0.547945
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# ...

# %%
missing_value_clm_gre_20 = missing_value_per[missing_value_per > 17].keys()

missing_value_clm_gre_20
# Out:
# Index(['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
df2 = df.drop(columns = missing_value_clm_gre_20)

df2.shape
# Out:
# (1460, 75)

# %%
df3 = df2.select_dtypes(include = ['int64', 'float64'])

df3.head()
# Out:
#    Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0   1          60     8450            7            5       2003          2003
# 1   2          20     9600            6            8       1976          1976
# 2   3          60    11250            7            5       2001          2002
# 3   4          70     9550            7            5       1915          1970
# 4   5          60    14260            8            5       2000          2000
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0       196.0         706           0        150          856       856
# 1         0.0         978           0        284         1262      1262
# 2       162.0         486           0        434          920       920
# 3         0.0         216           0        540          756       961
# 4       350.0         655           0        490         1145      1145
#
# ...

# %%
plt.figure(figsize = (16,14))
sns.heatmap(df3.isnull())
# Out:
# <Axes: >

# %%
df3[df3.isnull().any(axis=1)]
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 39      40          90     6040            4            5       1955
# 48      49         190     4456            4            5       1920
# 78      79          90    10778            4            5       1968
# 88      89          50     8470            3            2       1915
# 89      90          20     8070            4            5       1994
# 99     100          20     9320            4            5       1959
# 108    109          50     8500            5            7       1919
# 125    126         190     6780            6            8       1935
# 127    128          45     4388            5            7       1930
# 140    141          20    10500            4            5       1971
# 148    149          20     7500            7            5       2004
# 155    156          50     9600            6            5       1924
# 163    164          45     5500            4            6       1956
# ...

# %%
df3.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# LotArea           0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# MasVnrArea        8
# BsmtFinSF1        0
# BsmtFinSF2        0
# BsmtUnfSF         0
# TotalBsmtSF       0
# 1stFlrSF          0
# 2ndFlrSF          0
# LowQualFinSF      0
# GrLivArea         0
# BsmtFullBath      0
# BsmtHalfBath      0
# FullBath          0
# HalfBath          0
# BedroomAbvGr      0
# KitchenAbvGr      0
# TotRmsAbvGrd      0
# Fireplaces        0
# GarageYrBlt      81
# GarageCars        0
# GarageArea        0
# WoodDeckSF        0
# OpenPorchSF       0
# EnclosedPorch     0
# 3SsnPorch         0
# ScreenPorch       0
# PoolArea          0
# MiscVal           0
# MoSold            0
# YrSold            0
# SalePrice         0
# dtype: int64

# %%
missing_value_var = [var for var in df3.columns if df3[var].isnull().sum()>0]

missing_value_var
# Out:
# ['MasVnrArea', 'GarageYrBlt']

# %%
plt.figure(figsize = (16,9))

sns.set()
for i, var in enumerate(missing_value_var):
    plt.subplot(2,2,i+1)
    sns.distplot(df3[var], bins =20, kde_kws = {'linewidth':5, 'color':'#DC143C'})
# Out:
# C:\Users\Nitesh\AppData\Local\Temp\ipykernel_18704\827525339.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3[var], bins =20, kde_kws = {'linewidth':5, 'color':'#DC143C'})
# C:\Users\Nitesh\AppData\Local\Temp\ipykernel_18704\827525339.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # Mean

# %%
df4  = df3.fillna(df3.mean())

df4.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize = (16,9))
sns.set()

for i, var in enumerate(missing_value_var):
    plt.subplot(2,2,i+1)
    sns.distplot(df3[var], bins =20, kde_kws = {'linewidth':8, 'color':'red'},label = "Original")
    sns.distplot(df4[var], bins =20, kde_kws = {'linewidth':5, 'color':'green'},label = "Mean Value")
    plt.legend()
# Out:
# C:\Users\Nitesh\AppData\Local\Temp\ipykernel_18704\2283520793.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3[var], bins =20, kde_kws = {'linewidth':8, 'color':'red'},label = "Original")
# C:\Users\Nitesh\AppData\Local\Temp\ipykernel_18704\2283520793.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # Median

# %%
df5  = df3.fillna(df3.median())

df5.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize = (16,9))
sns.set()

for i, var in enumerate(missing_value_var):
    plt.subplot(2,2,i+1)
    sns.distplot(df3[var], bins =20, kde_kws = {'linewidth':8, 'color':'red'},label = "Original")
    sns.distplot(df5[var], bins =20, kde_kws = {'linewidth':5, 'color':'green'},label = "Median Value")
    plt.legend()
# Out:
# C:\Users\Nitesh\AppData\Local\Temp\ipykernel_18704\3632519391.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3[var], bins =20, kde_kws = {'linewidth':8, 'color':'red'},label = "Original")
# C:\Users\Nitesh\AppData\Local\Temp\ipykernel_18704\3632519391.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
plt.figure(figsize = (16,9))
sns.set()

for i, var in enumerate(missing_value_var):
    plt.subplot(2,2,i+1)
    sns.distplot(df3[var], bins =20, kde_kws = {'linewidth':8, 'color':'red'},label = "Original")
    sns.distplot(df4[var], bins =20, kde_kws = {'linewidth':5, 'color':'green'},label = "Mean Value")
    sns.distplot(df5[var], bins =20, kde_kws = {'linewidth':3, 'color':'k'},label = "Median Value")
    plt.legend()
# Out:
# C:\Users\Nitesh\AppData\Local\Temp\ipykernel_18704\1112109045.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3[var], bins =20, kde_kws = {'linewidth':8, 'color':'red'},label = "Original")
# C:\Users\Nitesh\AppData\Local\Temp\ipykernel_18704\1112109045.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
plt.figure(figsize = (16,9))
sns.set()

for i, var in enumerate(missing_value_var):
    plt.subplot(2,2,i+1)
    sns.distplot(df3[var], bins =20,hist = False, kde_kws = {'linewidth':8, 'color':'red'},label = "Original")
    sns.distplot(df4[var], bins =20,hist = False, kde_kws = {'linewidth':5, 'color':'green'},label = "Mean Value")
    sns.distplot(df5[var], bins =20,hist = False, kde_kws = {'linewidth':3, 'color':'k'},label = "Median Value")
    plt.legend()
# Out:
# C:\Users\Nitesh\AppData\Local\Temp\ipykernel_18704\268917048.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3[var], bins =20,hist = False, kde_kws = {'linewidth':8, 'color':'red'},label = "Original")
# C:\Users\Nitesh\AppData\Local\Temp\ipykernel_18704\268917048.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
for i, var in enumerate(missing_value_var):
    plt.figure(figsize = (10,10))
    plt.subplot(3,1,1)
    sns.boxplot(df[var])
    plt.subplot(3,1,2)
    sns.boxplot(df4[var])
    plt.subplot(3,1,3)
    sns.boxplot(df5[var])

# %%
df_concat  = pd.concat([df3[missing_value_var],df4[missing_value_var],df3[missing_value_var]], axis =1)

# %%
df_concat[df_concat.isnull().any(axis=1)]
# Out:
#       MasVnrArea  GarageYrBlt  MasVnrArea  GarageYrBlt  MasVnrArea  \
# 39           0.0          NaN    0.000000  1978.506164         0.0
# 48           0.0          NaN    0.000000  1978.506164         0.0
# 78           0.0          NaN    0.000000  1978.506164         0.0
# 88           0.0          NaN    0.000000  1978.506164         0.0
# 89           0.0          NaN    0.000000  1978.506164         0.0
# 99           0.0          NaN    0.000000  1978.506164         0.0
# 108          0.0          NaN    0.000000  1978.506164         0.0
# 125          0.0          NaN    0.000000  1978.506164         0.0
# 127          0.0          NaN    0.000000  1978.506164         0.0
# 140          0.0          NaN    0.000000  1978.506164         0.0
# 148        120.0          NaN  120.000000  1978.506164       120.0
# 155          0.0          NaN    0.000000  1978.506164         0.0
# 163          0.0          NaN    0.000000  1978.506164         0.0
# ...
